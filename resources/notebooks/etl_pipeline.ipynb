# %%
# ============================================
# ETL Pipeline - Ingesta y Transformación
# ============================================

from pyspark.sql import functions as F
from pyspark.sql.types import DoubleType
from datetime import datetime

# Configuración
CATALOG = "datasets_github_projects"
SCHEMA = "default"
SOURCE_TABLE = "ventas_raw"
TARGET_TABLE = "ventas_transformed"

print(f"🚀 Pipeline iniciado: {datetime.now()}")
print(f"📊 Origen: {CATALOG}.{SCHEMA}.{SOURCE_TABLE}")
# Out:
# 🚀 Pipeline iniciado: 2025-11-02 04:12:55.258776
# 📊 Origen: datasets_github_projects.default.ventas_raw

# %%
# Leer datos desde la tabla Delta
df_raw = spark.table(f"{CATALOG}.{SCHEMA}.{SOURCE_TABLE}")

print(f"✅ Datos cargados: {df_raw.count()} registros")
print("\n📋 Esquema:")
df_raw.printSchema()
print("\n👀 Primeras 5 filas:")
display(df_raw.limit(5))
# Out:
# ✅ Datos cargados: 10 registros
#
# 📋 Esquema:
# root
#  |-- order_id: long (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- quantity: long (nullable = true)
#  |-- price: double (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- country: string (nullable = true)
#
#
# 👀 Primeras 5 filas:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_id</th><th>product_name</th><th>category</th><th>quantity</th><th>price</th><th>order_date</th><th>country</th></tr></thead><tbody><tr><td>1001</td><td>C001</td><td>Laptop</td><td>Electronics</td><td>1</td><td>1200.5</td><td>2024-01-15</td><td>Colombia</td></tr><tr><td>1002</td><td>C002</td><td>Mouse</td><td>Electronics</td><td>2</td><td>25.99</td><td>2024-01-15</td><td>Mexico</td></tr><tr><td>1003</td><td>C001</td><td>Keyboard</td><td>Electronics</td><td>1</td><td>75.0</td><td>2024-01-16</td><td>Colombia</td></tr><tr><td>1004</td><td>C003</td><td>Chair</td><td>Furniture</td><td>4</td><td>150.0</td><td>2024-01-16</td><td>USA</td></tr><tr><td>1005</td><td>C002</td><td>Monitor</td><td>Electronics</td><td>1</td><td>300.0</td><td>2024-01-17</td><td>Mexico</td></tr></tbody></table></div>

# %%
# Validaciones iniciales
print("🔍 ANÁLISIS EXPLORATORIO\n")

# Conteo por categoría
print("📦 Productos por categoría:")
df_raw.groupBy("category").count().orderBy(F.desc("count")).show()

# Verificar nulos
print("\n🚨 Valores nulos por columna:")
df_raw.select([F.count(F.when(F.col(c).isNull(), c)).alias(c) for c in df_raw.columns]).show()

# Rango de fechas
print("\n📅 Rango temporal:")
df_raw.select(F.min("order_date"), F.max("order_date")).show()
# Out:
# 🔍 ANÁLISIS EXPLORATORIO
#
# 📦 Productos por categoría:
# +-----------+-----+
# |   category|count|
# +-----------+-----+
# |Electronics|    6|
# |  Furniture|    3|
# | Stationery|    1|
# +-----------+-----+
#
#
# 🚨 Valores nulos por columna:
# +--------+-----------+------------+--------+--------+-----+----------+-------+
# |order_id|customer_id|product_name|category|quantity|price|order_date|country|
# +--------+-----------+------------+--------+--------+-----+----------+-------+
# |       0|          0|           0|       0|       0|    0|         0|      0|
# +--------+-----------+------------+--------+--------+-----+----------+-------+
#
#
# 📅 Rango temporal:
# +---------------+---------------+
# |min(order_date)|max(order_date)|
# +---------------+---------------+
# |     2024-01-15|     2024-01-19|
# +---------------+---------------+

# %%
# ============================================
# TRANSFORMACIONES
# ============================================

df_transformed = (
    df_raw
    # Calcular monto total por orden
    .withColumn("total_amount", F.col("quantity") * F.col("price"))
    
    # Extraer componentes de fecha
    .withColumn("year", F.year("order_date"))
    .withColumn("month", F.month("order_date"))
    .withColumn("day_of_week", F.dayofweek("order_date"))
    
    # Clasificar por volumen de compra
    .withColumn("order_size", 
        F.when(F.col("quantity") >= 10, "Large")
         .when(F.col("quantity") >= 5, "Medium")
         .otherwise("Small")
    )
    
    # Categorizar por precio unitario
    .withColumn("price_category",
        F.when(F.col("price") >= 500, "Premium")
         .when(F.col("price") >= 100, "Standard")
         .otherwise("Budget")
    )
    
    # Timestamp de procesamiento
    .withColumn("processed_at", F.current_timestamp())
)

print("✅ Transformaciones aplicadas")
print(f"📊 Total de columnas: {len(df_transformed.columns)}")
print("\n📋 Nuevas columnas agregadas:")
print("  - total_amount: quantity * price")
print("  - year, month, day_of_week: componentes temporales")
print("  - order_size: clasificación por volumen")
print("  - price_category: clasificación por precio")
print("  - processed_at: timestamp de procesamiento")
# Out:
# ✅ Transformaciones aplicadas
# 📊 Total de columnas: 15
#
# 📋 Nuevas columnas agregadas:
#   - total_amount: quantity * price
#   - year, month, day_of_week: componentes temporales
#   - order_size: clasificación por volumen
#   - price_category: clasificación por precio
#   - processed_at: timestamp de procesamiento

# %%
# Validar resultados
print("🔍 VALIDACIÓN DE TRANSFORMACIONES\n")

# Mostrar muestra con nuevas columnas
print("👀 Muestra de datos transformados:")
display(
    df_transformed
    .select("order_id", "product_name", "quantity", "price", 
            "total_amount", "order_size", "price_category")
    .limit(10)
)

# Estadísticas de montos
print("\n💰 Estadísticas de montos totales:")
df_transformed.select(
    F.min("total_amount").alias("min_amount"),
    F.max("total_amount").alias("max_amount"),
    F.avg("total_amount").alias("avg_amount"),
    F.sum("total_amount").alias("total_revenue")
).show()

# Distribución por tamaño de orden
print("\n📊 Distribución por tamaño de orden:")
df_transformed.groupBy("order_size").count().orderBy("order_size").show()
# Out:
# 🔍 VALIDACIÓN DE TRANSFORMACIONES
#
# 👀 Muestra de datos transformados:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>product_name</th><th>quantity</th><th>price</th><th>total_amount</th><th>order_size</th><th>price_category</th></tr></thead><tbody><tr><td>1001</td><td>Laptop</td><td>1</td><td>1200.5</td><td>1200.5</td><td>Small</td><td>Premium</td></tr><tr><td>1002</td><td>Mouse</td><td>2</td><td>25.99</td><td>51.98</td><td>Small</td><td>Budget</td></tr><tr><td>1003</td><td>Keyboard</td><td>1</td><td>75.0</td><td>75.0</td><td>Small</td><td>Budget</td></tr><tr><td>1004</td><td>Chair</td><td>4</td><td>150.0</td><td>600.0</td><td>Small</td><td>Standard</td></tr><tr><td>1005</td><td>Monitor</td><td>1</td><td>300.0</td><td>300.0</td><td>Small</td><td>Standard</td></tr><tr><td>1006</td><td>Desk</td><td>2</td><td>450.0</td><td>900.0</td><td>Small</td><td>Standard</td></tr><tr><td>1007</td><td>Headphones</td><td>3</td><td>80.0</td><td>240.0</td><td>Small</td><td>Budget</td></tr><tr><td>1008</td><td>Lamp</td><td>5</td><td>35.5</td><td>177.5</td><td>Medium</td><td>Budget</td></tr><tr><td>1009</td><td>USB Cable</td><td>10</td><td>5.99</td><td>59.900000000000006</td><td>Large</td><td>Budget</td></tr><tr><td>1010</td><td>Notebook</td><td>20</td><td>2.5</td><td>50.0</td><td>Large</td><td>Budget</td></tr></tbody></table></div>
# 💰 Estadísticas de montos totales:
# +----------+----------+----------+-------------+
# |min_amount|max_amount|avg_amount|total_revenue|
# +----------+----------+----------+-------------+
# |      50.0|    1200.5|   365.488|      3654.88|
# +----------+----------+----------+-------------+
#
#
# 📊 Distribución por tamaño de orden:
# +----------+-----+
# |order_size|count|
# +----------+-----+
# |     Large|    2|
# |    Medium|    1|
# |     Small|    7|
# +----------+-----+

# %%
# ============================================
# MÉTRICAS DE NEGOCIO
# ============================================

# Ventas por país
ventas_por_pais = (
    df_transformed
    .groupBy("country")
    .agg(
        F.count("order_id").alias("num_orders"),
        F.sum("total_amount").alias("total_sales"),
        F.avg("total_amount").alias("avg_order_value")
    )
    .orderBy(F.desc("total_sales"))
)

print("🌎 VENTAS POR PAÍS:")
display(ventas_por_pais)

# Ventas por categoría
ventas_por_categoria = (
    df_transformed
    .groupBy("category")
    .agg(
        F.count("order_id").alias("num_orders"),
        F.sum("total_amount").alias("total_sales"),
        F.sum("quantity").alias("total_units")
    )
    .orderBy(F.desc("total_sales"))
)

print("\n📦 VENTAS POR CATEGORÍA:")
display(ventas_por_categoria)
# Out:
# 🌎 VENTAS POR PAÍS:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>num_orders</th><th>total_sales</th><th>avg_order_value</th></tr></thead><tbody><tr><td>Colombia</td><td>4</td><td>2235.4</td><td>558.85</td></tr><tr><td>USA</td><td>2</td><td>777.5</td><td>388.75</td></tr><tr><td>Mexico</td><td>2</td><td>351.98</td><td>175.99</td></tr><tr><td>Spain</td><td>1</td><td>240.0</td><td>240.0</td></tr><tr><td>Argentina</td><td>1</td><td>50.0</td><td>50.0</td></tr></tbody></table></div>
# 📦 VENTAS POR CATEGORÍA:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>num_orders</th><th>total_sales</th><th>total_units</th></tr></thead><tbody><tr><td>Electronics</td><td>6</td><td>1927.38</td><td>18</td></tr><tr><td>Furniture</td><td>3</td><td>1677.5</td><td>11</td></tr><tr><td>Stationery</td><td>1</td><td>50.0</td><td>20</td></tr></tbody></table></div>

# %%
# ============================================
# ESCRITURA A DELTA LAKE
# ============================================

# Definir ruta de salida
output_table = f"{CATALOG}.{SCHEMA}.{TARGET_TABLE}"

# Escribir como tabla Delta
(
    df_transformed
    .write
    .format("delta")
    .mode("overwrite")  # En producción usarías append o merge
    .option("overwriteSchema", "true")
    .saveAsTable(output_table)
)

print(f"✅ Datos guardados exitosamente en: {output_table}")
print(f"📊 Total de registros escritos: {df_transformed.count()}")
# Out:
# ✅ Datos guardados exitosamente en: datasets_github_projects.default.ventas_transformed
# 📊 Total de registros escritos: 10

# %%
# Verificar que la tabla existe y es accesible
df_check = spark.table(output_table)

print(f"🔍 VALIDACIÓN DE TABLA CREADA\n")
print(f"📋 Tabla: {output_table}")
print(f"📊 Registros: {df_check.count()}")
print(f"📁 Columnas: {len(df_check.columns)}")

# Mostrar esquema de la tabla final
print("\n📋 Esquema de tabla transformada:")
df_check.printSchema()

# Verificar metadatos Delta
print("\n📜 Historial de la tabla (Delta Lake):")
display(spark.sql(f"DESCRIBE HISTORY {output_table}").limit(5))
# Out:
# 🔍 VALIDACIÓN DE TABLA CREADA
#
# 📋 Tabla: datasets_github_projects.default.ventas_transformed
# 📊 Registros: 10
# 📁 Columnas: 15
#
# 📋 Esquema de tabla transformada:
# root
#  |-- order_id: long (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- quantity: long (nullable = true)
#  |-- price: double (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- country: string (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- day_of_week: integer (nullable = true)
#  |-- order_size: string (nullable = true)
#  |-- price_category: string (nullable = true)
#  |-- processed_at: timestamp (nullable = true)
#
#
# 📜 Historial de la tabla (Delta Lake):
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>0</td><td>2025-11-02T04:17:07.000Z</td><td>78303099390903</td><td>msosa@unal.edu.co</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"delta.parquet.compression.codec":"zstd","delta.enableDeletionVectors":"true"}, statsOnLoad -> true)</td><td>null</td><td>List(300599389944397)</td><td>1102-040923-m4ryxk2n-v2n</td><td>null</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 1, numRemovedFiles -> 0, numRemovedBytes -> 0, numDeletionVectorsRemoved -> 0, numOutputRows -> 10, numOutputBytes -> 4507)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr></tbody></table></div>

# %%
# ============================================
# RESUMEN DEL PIPELINE
# ============================================

print("=" * 60)
print("✅ PIPELINE COMPLETADO EXITOSAMENTE")
print("=" * 60)

print(f"\n📥 Origen:")
print(f"   Tabla: {CATALOG}.{SCHEMA}.{SOURCE_TABLE}")
print(f"   Registros: {df_raw.count()}")

print(f"\n📤 Destino:")
print(f"   Tabla: {output_table}")
print(f"   Registros: {df_transformed.count()}")

print(f"\n🔧 Transformaciones aplicadas:")
print(f"   - Cálculo de monto total (quantity × price)")
print(f"   - Extracción de componentes temporales")
print(f"   - Clasificación por tamaño de orden")
print(f"   - Categorización por precio")
print(f"   - Timestamp de procesamiento")

print(f"\n⏱️  Pipeline finalizado: {datetime.now()}")
print("=" * 60)
# Out:
# ============================================================
# ✅ PIPELINE COMPLETADO EXITOSAMENTE
# ============================================================
#
# 📥 Origen:
#    Tabla: datasets_github_projects.default.ventas_raw
#    Registros: 10
#
# 📤 Destino:
#    Tabla: datasets_github_projects.default.ventas_transformed
#    Registros: 10
#
# 🔧 Transformaciones aplicadas:
#    - Cálculo de monto total (quantity × price)
#    - Extracción de componentes temporales
#    - Clasificación por tamaño de orden
#    - Categorización por precio
#    - Timestamp de procesamiento
#
# ⏱️  Pipeline finalizado: 2025-11-02 04:17:22.510562
# ============================================================

# %%
# Nueva celda de prueba
print("🎉 Editado desde VS Code!")
