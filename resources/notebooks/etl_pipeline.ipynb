# %%
# ETL Pipeline - Production Implementation
from src.config.settings import Config
from src.extract.data_loader import DataLoader
from src.transform.transformations import SalesTransformer
from src.validation.data_quality import DataQualityValidator
from src.load.data_writer import DeltaWriter
from src.utils.logger import setup_logger
from datetime import datetime
from pyspark.sql import functions as F

# %%
# Setup
config = Config()
logger = setup_logger("etl_pipeline", level="INFO")
logger.info("ETL Pipeline Started")
logger.info(f"Source: {config.source_table_full}")
logger.info(f"Target: {config.target_table_full}")

# %%
# Extract
loader = DataLoader(spark, config)
df_raw = loader.load_source_data()
record_count = df_raw.count()
logger.info(f"Loaded {record_count} records")
display(df_raw.limit(5))

# %%
# Validate
validator = DataQualityValidator(config)
quality_report = validator.validate(df_raw)
report_lines = validator.generate_quality_report(quality_report)
for line in report_lines:
    print(line)

# %%
# Transform
transformer = SalesTransformer(config)
df_transformed = transformer.transform(df_raw)
logger.info(f"Transformed {df_transformed.count()} records")
display(df_transformed.select("order_id", "total_amount", "order_size", "price_category").limit(10))

# %%
# Business Metrics
print("Financial Statistics:")
df_transformed.select(
    F.min("total_amount").alias("min"),
    F.max("total_amount").alias("max"),
    F.avg("total_amount").alias("avg"),
    F.sum("total_amount").alias("total")
).show()

print("Sales by Country:")
display(df_transformed.groupBy("country").agg(
    F.count("*").alias("orders"),
    F.sum("total_amount").alias("sales")
).orderBy(F.desc("sales")))

# %%
# Load (Upsert)
writer = DeltaWriter(spark, config)
stats = writer.upsert(df_transformed, merge_key="order_id")
logger.info("Data written successfully")
print("Write Statistics:", stats)

# %%
# Verification
df_check = spark.table(config.target_table_full)
print(f"Target table: {config.target_table_full}")
print(f"Records: {df_check.count()}")
display(spark.sql(f"DESCRIBE HISTORY {config.target_table_full}").limit(3))

# %%
# Summary
print("="*60)
print("Pipeline Completed Successfully")
print("="*60)
print(f"Source: {record_count} records")
print(f"Target: {df_check.count()} records")
print(f"Quality Status: {quality_report['summary']['status']}")
logger.info("Pipeline execution complete")
